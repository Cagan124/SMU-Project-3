# %%
import pandas as pd
import matplotlib.pyplot as plt
import locale 
from math import radians, sin, cos, sqrt, atan2

# %%
df = pd.read_csv("Resources/NY-House-Dataset.csv")
df.head()
# Out:
#                                          BROKERTITLE                TYPE  \
# 0        Brokered by Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                                Brokered by Serhant      Condo for sale
# 2                             Brokered by Sowae Corp      House for sale
# 3                                Brokered by COMPASS      Condo for sale
# 4  Brokered by Sotheby's International Realty - E...  Townhouse for sale
#
#        PRICE  BEDS       BATH  PROPERTYSQFT  \
# 0     315000     2   2.000000        1400.0
# 1  195000000     7  10.000000       17545.0
# 2     260000     4   2.000000        2015.0
# 3      69000     3   1.000000         445.0
# 4   55000000     7   2.373861       14175.0
#
#                                              ADDRESS                    STATE  \
# 0                               2 E 55th St Unit 803       New York, NY 10022
# 1  Central Park Tower Penthouse-217 W 57th New Yo...       New York, NY 10019
# 2                                   620 Sinclair Ave  Staten Island, NY 10312
# 3                            2 E 55th St Unit 908W33      Manhattan, NY 10022
# 4                                        5 E 64th St       New York, NY 10065
#
#                                         MAIN_ADDRESS  \
# 0             2 E 55th St Unit 803New York, NY 10022
# 1  Central Park Tower Penthouse-217 W 57th New Yo...
# 2            620 Sinclair AveStaten Island, NY 10312
# 3         2 E 55th St Unit 908W33Manhattan, NY 10022
# 4                      5 E 64th StNew York, NY 10065
#
#   ADMINISTRATIVE_AREA_LEVEL_2  LOCALITY      SUBLOCALITY       STREET_NAME  \
# 0             New York County  New York        Manhattan  East 55th Street
# 1               United States  New York  New York County          New York
# 2               United States  New York  Richmond County     Staten Island
# 3               United States  New York  New York County          New York
# 4               United States  New York  New York County          New York
#
#           LONG_NAME                                  FORMATTED_ADDRESS  \
# 0   Regis Residence  Regis Residence, 2 E 55th St #803, New York, N...
# 1  West 57th Street             217 W 57th St, New York, NY 10019, USA
# 2   Sinclair Avenue     620 Sinclair Ave, Staten Island, NY 10312, USA
# 3  East 55th Street               2 E 55th St, New York, NY 10022, USA
# 4  East 64th Street               5 E 64th St, New York, NY 10065, USA
#
#     LATITUDE  LONGITUDE
# 0  40.761255 -73.974483
# 1  40.766393 -73.980991
# 2  40.541805 -74.196109
# 3  40.761398 -73.974613
# 4  40.767224 -73.969856

# %%
df.info()

# %%
# #data = {'PRICE': [df.PRICE]}
# df2 = pd.DataFrame(data)

# # Define the conversion function
# def convert_scientific_to_standard(number):
#     return "{:.0f}".format(number)

# # Apply the conversion function to the 'Value' column
# df2['PRICE'] = df2['PRICE'].apply(convert_scientific_to_standard)

# # Print the updated DataFrame
# print(df2)

# %%
 #Check any duplicate record

df.duplicated().sum()

# %%
# Drop duplicate records

df.drop_duplicates(inplace=True)

# %%
df = df[df['TYPE'].isin(['Land for sale'])==False] # leaving houses only

# %%
df.TYPE.unique()

# %%
df = df[df['TYPE'].isin(['Foreclosure'])==False]

# %%
df = df[df['TYPE'].isin(['Pending'])==False]

# %%
df = df[df['TYPE'].isin(['Coming Soon', 'Contingent', 'For sale', 'Mobile house for sale', 'Condop for sale'])==False]

# %%
df.info()

# %%
df.TYPE.unique()

# %%
df.TYPE.value_counts()

# %%
#df['PRICE'] = df['PRICE'].apply(lambda x: '{:.9f}'.format(float(x)))

# %%
df['PRICE'] = df['PRICE'].astype(float)
df['PRICE'] = df['PRICE'].apply(lambda x: '${:,.7f}'.format(x))

# %%
regions = df.groupby('TYPE').mean('PRICE')
regions.head()
# Out:
#                                    PRICE      BEDS      BATH  PROPERTYSQFT  \
# TYPE
# Co-op for sale              1.113426e+06  1.984870  1.438754   1658.496424
# Condo for sale              2.615780e+06  2.327791  2.002798   1571.731184
# House for sale              3.786544e+06  3.733954  2.532248   2254.455492
# Multi-family home for sale  1.666781e+06  6.261803  3.936427   3210.209600
# Townhouse for sale          6.406234e+06  5.020833  3.874356   3887.512776
#
#                              LATITUDE  LONGITUDE
# TYPE
# Co-op for sale              40.747603 -73.920662
# Condo for sale              40.724426 -73.954237
# House for sale              40.678153 -73.946532
# Multi-family home for sale  40.700932 -73.927708
# Townhouse for sale          40.718419 -73.971435

# %%
avg_price = regions.sort_values(by=['PRICE'], ascending=False)

# %%
regions.nunique()

# %%
# what are the top 10 sublocalities by price
data = avg_price

plt.barh(data.index, data.PRICE)
plt.xticks(rotation=60)
plt.show()

# %%
# Function to calculate distance between two points
def calculate_distance(lat1, lon1, lat2, lon2):
    # Convert latitude and longitude to radians
    lat1 = radians(lat1)
    lon1 = radians(lon1)
    lat2 = radians(lat2)
    lon2 = radians(lon2)
    
    # Radius of the Earth in miles
    R = 3958.8
    
    # Calculate the differences in latitude and longitude
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    
    # Apply the Haversine formula
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * atan2(sqrt(a), sqrt(1-a))
    distance = R * c
    
    return distance


# Enter the latitude and longitude of the point you want to calculate the distance from
my_latitude = 40.730610
my_longitude = -73.935242

df['Distance'] = df.apply(lambda row: calculate_distance(row['LATITUDE'], row['LONGITUDE'], my_latitude, my_longitude), axis=1)

# %%
df.head()
# Out:
#                                          BROKERTITLE                TYPE  \
# 0        Brokered by Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                                Brokered by Serhant      Condo for sale
# 2                             Brokered by Sowae Corp      House for sale
# 3                                Brokered by COMPASS      Condo for sale
# 4  Brokered by Sotheby's International Realty - E...  Townhouse for sale
#
#        PRICE  BEDS       BATH  PROPERTYSQFT  \
# 0     315000     2   2.000000        1400.0
# 1  195000000     7  10.000000       17545.0
# 2     260000     4   2.000000        2015.0
# 3      69000     3   1.000000         445.0
# 4   55000000     7   2.373861       14175.0
#
#                                              ADDRESS                    STATE  \
# 0                               2 E 55th St Unit 803       New York, NY 10022
# 1  Central Park Tower Penthouse-217 W 57th New Yo...       New York, NY 10019
# 2                                   620 Sinclair Ave  Staten Island, NY 10312
# 3                            2 E 55th St Unit 908W33      Manhattan, NY 10022
# 4                                        5 E 64th St       New York, NY 10065
#
#                                         MAIN_ADDRESS  \
# 0             2 E 55th St Unit 803New York, NY 10022
# 1  Central Park Tower Penthouse-217 W 57th New Yo...
# 2            620 Sinclair AveStaten Island, NY 10312
# 3         2 E 55th St Unit 908W33Manhattan, NY 10022
# 4                      5 E 64th StNew York, NY 10065
#
#   ADMINISTRATIVE_AREA_LEVEL_2  LOCALITY      SUBLOCALITY       STREET_NAME  \
# 0             New York County  New York        Manhattan  East 55th Street
# 1               United States  New York  New York County          New York
# 2               United States  New York  Richmond County     Staten Island
# 3               United States  New York  New York County          New York
# 4               United States  New York  New York County          New York
#
#           LONG_NAME                                  FORMATTED_ADDRESS  \
# 0   Regis Residence  Regis Residence, 2 E 55th St #803, New York, N...
# 1  West 57th Street             217 W 57th St, New York, NY 10019, USA
# 2   Sinclair Avenue     620 Sinclair Ave, Staten Island, NY 10312, USA
# 3  East 55th Street               2 E 55th St, New York, NY 10022, USA
# 4  East 64th Street               5 E 64th St, New York, NY 10065, USA
#
#     LATITUDE  LONGITUDE   Distance
# 0  40.761255 -73.974483   2.950061
# 1  40.766393 -73.980991   3.442019
# 2  40.541805 -74.196109  18.901470
# 3  40.761398 -73.974613   2.961863
# 4  40.767224 -73.969856   3.111680

# %%
df['PRICE_BY_SQFT'] = df['PRICE']/df['PROPERTYSQFT']

# %%
df.head()
# Out:
#                                          BROKERTITLE                TYPE  \
# 0        Brokered by Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                                Brokered by Serhant      Condo for sale
# 2                             Brokered by Sowae Corp      House for sale
# 3                                Brokered by COMPASS      Condo for sale
# 4  Brokered by Sotheby's International Realty - E...  Townhouse for sale
#
#        PRICE  BEDS       BATH  PROPERTYSQFT  \
# 0     315000     2   2.000000        1400.0
# 1  195000000     7  10.000000       17545.0
# 2     260000     4   2.000000        2015.0
# 3      69000     3   1.000000         445.0
# 4   55000000     7   2.373861       14175.0
#
#                                              ADDRESS                    STATE  \
# 0                               2 E 55th St Unit 803       New York, NY 10022
# 1  Central Park Tower Penthouse-217 W 57th New Yo...       New York, NY 10019
# 2                                   620 Sinclair Ave  Staten Island, NY 10312
# 3                            2 E 55th St Unit 908W33      Manhattan, NY 10022
# 4                                        5 E 64th St       New York, NY 10065
#
#                                         MAIN_ADDRESS  \
# 0             2 E 55th St Unit 803New York, NY 10022
# 1  Central Park Tower Penthouse-217 W 57th New Yo...
# 2            620 Sinclair AveStaten Island, NY 10312
# 3         2 E 55th St Unit 908W33Manhattan, NY 10022
# 4                      5 E 64th StNew York, NY 10065
#
#   ADMINISTRATIVE_AREA_LEVEL_2  LOCALITY      SUBLOCALITY       STREET_NAME  \
# 0             New York County  New York        Manhattan  East 55th Street
# 1               United States  New York  New York County          New York
# 2               United States  New York  Richmond County     Staten Island
# 3               United States  New York  New York County          New York
# 4               United States  New York  New York County          New York
#
#           LONG_NAME                                  FORMATTED_ADDRESS  \
# 0   Regis Residence  Regis Residence, 2 E 55th St #803, New York, N...
# 1  West 57th Street             217 W 57th St, New York, NY 10019, USA
# 2   Sinclair Avenue     620 Sinclair Ave, Staten Island, NY 10312, USA
# 3  East 55th Street               2 E 55th St, New York, NY 10022, USA
# 4  East 64th Street               5 E 64th St, New York, NY 10065, USA
#
#     LATITUDE  LONGITUDE   Distance  PRICE_BY_SQFT
# 0  40.761255 -73.974483   2.950061     225.000000
# 1  40.766393 -73.980991   3.442019   11114.277572
# 2  40.541805 -74.196109  18.901470     129.032258
# 3  40.761398 -73.974613   2.961863     155.056180
# 4  40.767224 -73.969856   3.111680    3880.070547

# %%
df2 = df.loc[df["PRICE_BY_SQFT"] ==  2147483647]
df2
# Out:
# Empty DataFrame
# Columns: [BROKERTITLE, TYPE, PRICE, BEDS, BATH, PROPERTYSQFT, ADDRESS, STATE, MAIN_ADDRESS, ADMINISTRATIVE_AREA_LEVEL_2, LOCALITY, SUBLOCALITY, STREET_NAME, LONG_NAME, FORMATTED_ADDRESS, LATITUDE, LONGITUDE, Distance, PRICE_BY_SQFT]
# Index: []

# %%
df2 = df.loc[df["PRICE"] !=  2147483647]
df2.sort_values(by = 'PRICE_BY_SQFT', ascending = False)
# Out:
#                                             BROKERTITLE  \
# 1075                                Brokered by COMPASS
# 1453                     Brokered by Corcoran East Side
# 3388  Brokered by Sotheby's International Realty - E...
# 3571  Brokered by Sotheby's International Realty - E...
# 1258                     Brokered by Corcoran West Side
# ...                                                 ...
# 1210  Brokered by LandSeAir Real Estate Group, Inc -...
# 3615            Brokered by CENTURY 21 Milestone Realty
# 723                                            NoBroker
# 759              Brokered by Keller Williams City Views
# 318                      Brokered by 5 Boro Realty Corp
#
#                             TYPE     PRICE  BEDS      BATH  PROPERTYSQFT  \
# 1075              Co-op for sale  60000000     8  8.000000   2184.207862
# 1453              Co-op for sale  48000000     5  2.373861   2184.207862
# 3388              Co-op for sale  45000000     5  2.373861   2184.207862
# 3571              Co-op for sale  44500000     5  6.000000   2184.207862
# 1258  Multi-family home for sale  34000000     3  8.000000   2184.207862
# ...                          ...       ...   ...       ...           ...
# 1210              Co-op for sale    119888     1  1.000000   2184.207862
# 3615              Co-op for sale    119000     3  1.000000   2184.207862
# 723               Co-op for sale    115000     3  1.000000   2184.207862
# 759               Co-op for sale    109000     1  1.000000   2184.207862
# 318               Condo for sale     99000     1  1.000000   2184.207862
#
#                            ADDRESS                STATE  \
# 1075           960 5th Ave Unit 12  Manhattan, NY 10075
# 1453         740 Park Ave # 4 & 5B   New York, NY 10021
# 3388              4 E 66th St Fl 7   New York, NY 10065
# 3571              2 E 67th St Fl 9   New York, NY 10065
# 1258                 217 W 21st St   New York, NY 10011
# ...                            ...                  ...
# 1210  112-50 Northern Blvd Unit 5E     Corona, NY 11368
# 3615         89-00 170 St Unit 11N    Jamaica, NY 11432
# 723         87-15 165th St Unit 6C    Jamaica, NY 11432
# 759           335 E 209th St Apt 4      Bronx, NY 10467
# 318        1368 E 92nd St Unit 300   Brooklyn, NY 11236
#
#                                       MAIN_ADDRESS  \
# 1075        960 5th Ave Unit 12Manhattan, NY 10075
# 1453       740 Park Ave # 4 & 5BNew York, NY 10021
# 3388            4 E 66th St Fl 7New York, NY 10065
# 3571            2 E 67th St Fl 9New York, NY 10065
# 1258               217 W 21st StNew York, NY 10011
# ...                                            ...
# 1210  112-50 Northern Blvd Unit 5ECorona, NY 11368
# 3615        89-00 170 St Unit 11NJamaica, NY 11432
# 723        87-15 165th St Unit 6CJamaica, NY 11432
# 759            335 E 209th St Apt 4Bronx, NY 10467
# 318      1368 E 92nd St Unit 300Brooklyn, NY 11236
#
#      ADMINISTRATIVE_AREA_LEVEL_2         LOCALITY      SUBLOCALITY  \
# 1075                    New York  New York County         New York
# 1453                    New York  New York County         New York
# 3388                    New York  New York County         New York
# 3571                    New York  New York County         New York
# 1258               United States         New York  New York County
# ...                          ...              ...              ...
# 1210                    New York    Queens County           Queens
# 3615                    New York    Queens County           Queens
# 723                     New York    Queens County           Queens
# 759                     New York     Bronx County        The Bronx
# 318                     New York     Kings County         Brooklyn
#
#      STREET_NAME         LONG_NAME  \
# 1075   Manhattan               960
# 1453   Manhattan               740
# 3388   Manhattan                 4
# 3571   Manhattan                 2
# 1258    New York  West 21st Street
# ...          ...               ...
# 1210      Corona            112-50
# 3615     Jamaica              8900
# 723      Jamaica             87-15
# 759      Norwood               335
# 318     Canarsie              1368
#
#                                     FORMATTED_ADDRESS   LATITUDE  LONGITUDE  \
# 1075         960 5th Ave #12, New York, NY 10075, USA  40.775642 -73.964247
# 1453         740 Park Ave #5, New York, NY 10021, USA  40.770752 -73.964528
# 3388        4 E 66th St Fl 7, New York, NY 10065, USA  40.768301 -73.969734
# 3571        2 E 67th St Fl 9, New York, NY 10065, USA  40.768973 -73.969136
# 1258           217 W 21st St, New York, NY 10011, USA  40.743390 -73.997378
# ...                                               ...        ...        ...
# 1210  112-50 Northern Blvd #5e, Corona, NY 11368, USA  40.758223 -73.855922
# 3615    8900 170th St Apt 11l, Jamaica, NY 11432, USA  40.709570 -73.791130
# 723        87-15 165th St #6c, Jamaica, NY 11432, USA  40.710451 -73.798206
# 759        335 E 209th St Apt 4, Bronx, NY 10467, USA  40.876871 -73.874264
# 318      1368 E 92nd St #300, Brooklyn, NY 11236, USA  40.637254 -73.900267
#
#        Distance  PRICE_BY_SQFT
# 1075   3.462067   27469.913026
# 1453   3.168978   21975.930421
# 3388   3.168836   20602.434770
# 3571   3.189594   20373.518828
# 1258   3.370735   15566.284048
# ...         ...            ...
# 1210   4.569583      54.888549
# 3615   7.685429      54.481994
# 723    7.309997      52.650667
# 759   10.597078      49.903675
# 318    6.705566      45.325356
#
# [4182 rows x 19 columns]

# %%
df.TYPE.unique()
# Out:
# array(['Condo for sale', 'House for sale', 'Townhouse for sale',
#        'Co-op for sale', 'Multi-family home for sale'], dtype=object)

# %%
df_one = df['PRICE_BY_SQFT'].astype(float).quantile(0.99)
df = df.loc[df['PRICE_BY_SQFT'] <= df_one]
outliers_df.head()
x_label = "Years"
y_label = "Adjusted Earnings (US$ MM)"
fig_name = "Scatter without outliers"
# linear_regression_plot(outliers_df.Year.astype(float), outliers_df.Adjusted_Earnings.astype(float), x_label, y_label,(2015,10), fig_name)
outliers_df.count()
# Out:
# BROKERTITLE                    4141
# TYPE                           4141
# PRICE                          4141
# BEDS                           4141
# BATH                           4141
# PROPERTYSQFT                   4141
# ADDRESS                        4141
# STATE                          4141
# MAIN_ADDRESS                   4141
# ADMINISTRATIVE_AREA_LEVEL_2    4141
# LOCALITY                       4141
# SUBLOCALITY                    4141
# STREET_NAME                    4141
# LONG_NAME                      4141
# FORMATTED_ADDRESS              4141
# LATITUDE                       4141
# LONGITUDE                      4141
# Distance                       4141
# PRICE_BY_SQFT                  4141
# dtype: int64

# %%
df.head()
# Out:
#                                          BROKERTITLE                TYPE  \
# 0        Brokered by Douglas Elliman  -111 Fifth Ave      Condo for sale
# 2                             Brokered by Sowae Corp      House for sale
# 3                                Brokered by COMPASS      Condo for sale
# 4  Brokered by Sotheby's International Realty - E...  Townhouse for sale
# 5                             Brokered by Sowae Corp      House for sale
#
#       PRICE  BEDS      BATH  PROPERTYSQFT                  ADDRESS  \
# 0    315000     2  2.000000        1400.0     2 E 55th St Unit 803
# 2    260000     4  2.000000        2015.0         620 Sinclair Ave
# 3     69000     3  1.000000         445.0  2 E 55th St Unit 908W33
# 4  55000000     7  2.373861       14175.0              5 E 64th St
# 5    690000     5  2.000000        4004.0              584 Park Pl
#
#                      STATE                                MAIN_ADDRESS  \
# 0       New York, NY 10022      2 E 55th St Unit 803New York, NY 10022
# 2  Staten Island, NY 10312     620 Sinclair AveStaten Island, NY 10312
# 3      Manhattan, NY 10022  2 E 55th St Unit 908W33Manhattan, NY 10022
# 4       New York, NY 10065               5 E 64th StNew York, NY 10065
# 5       Brooklyn, NY 11238               584 Park PlBrooklyn, NY 11238
#
#   ADMINISTRATIVE_AREA_LEVEL_2  LOCALITY      SUBLOCALITY       STREET_NAME  \
# 0             New York County  New York        Manhattan  East 55th Street
# 2               United States  New York  Richmond County     Staten Island
# 3               United States  New York  New York County          New York
# 4               United States  New York  New York County          New York
# 5               United States  New York     Kings County          Brooklyn
#
#           LONG_NAME                                  FORMATTED_ADDRESS  \
# 0   Regis Residence  Regis Residence, 2 E 55th St #803, New York, N...
# 2   Sinclair Avenue     620 Sinclair Ave, Staten Island, NY 10312, USA
# 3  East 55th Street               2 E 55th St, New York, NY 10022, USA
# 4  East 64th Street               5 E 64th St, New York, NY 10065, USA
# 5        Park Place               584 Park Pl, Brooklyn, NY 11238, USA
#
#     LATITUDE  LONGITUDE   Distance  PRICE_BY_SQFT
# 0  40.761255 -73.974483   2.950061     225.000000
# 2  40.541805 -74.196109  18.901470     129.032258
# 3  40.761398 -73.974613   2.961863     155.056180
# 4  40.767224 -73.969856   3.111680    3880.070547
# 5  40.674363 -73.958725   4.076335     172.327672

# %%
house_type = 'House for sale'
house_type_df = df.loc[df["TYPE"] ==  house_type]
house_type_df.head()
# Out:
#                           BROKERTITLE            TYPE     PRICE  BEDS  BATH  \
# 2              Brokered by Sowae Corp  House for sale    260000     4   2.0
# 5              Brokered by Sowae Corp  House for sale    690000     5   2.0
# 7   Brokered by Connie Profaci Realty  House for sale  16800000     8  16.0
# 20    Brokered by Radiant Estates LLC  House for sale    639999     3   2.0
# 24        Brokered by Elizabeth Marra  House for sale    750000     2   2.0
#
#     PROPERTYSQFT           ADDRESS                    STATE  \
# 2         2015.0  620 Sinclair Ave  Staten Island, NY 10312
# 5         4004.0       584 Park Pl       Brooklyn, NY 11238
# 7        33000.0   177 Benedict Rd  Staten Island, NY 10304
# 20        1260.0      27 Clove Way  Staten Island, NY 10301
# 24        1330.0    280 Loretto St  Staten Island, NY 10307
#
#                                MAIN_ADDRESS ADMINISTRATIVE_AREA_LEVEL_2  \
# 2   620 Sinclair AveStaten Island, NY 10312               United States
# 5             584 Park PlBrooklyn, NY 11238               United States
# 7    177 Benedict RdStaten Island, NY 10304               United States
# 20      27 Clove WayStaten Island, NY 10301               United States
# 24    280 Loretto StStaten Island, NY 10307               United States
#
#     LOCALITY      SUBLOCALITY    STREET_NAME        LONG_NAME  \
# 2   New York  Richmond County  Staten Island  Sinclair Avenue
# 5   New York     Kings County       Brooklyn       Park Place
# 7   New York  Richmond County  Staten Island    Benedict Road
# 20  New York  Richmond County  Staten Island        Clove Way
# 24  New York  Richmond County  Staten Island   Loretto Street
#
#                                  FORMATTED_ADDRESS   LATITUDE  LONGITUDE  \
# 2   620 Sinclair Ave, Staten Island, NY 10312, USA  40.541805 -74.196109
# 5             584 Park Pl, Brooklyn, NY 11238, USA  40.674363 -73.958725
# 7    177 Benedict Rd, Staten Island, NY 10304, USA  40.595002 -74.106424
# 20      27 Clove Way, Staten Island, NY 10301, USA  40.620740 -74.111436
# 24    280 Loretto St, Staten Island, NY 10307, USA  40.503979 -74.239655
#
#      Distance  PRICE_BY_SQFT
# 2   18.901470     129.032258
# 5    4.076335     172.327672
# 7   12.972564     509.090909
# 20  11.953013     507.935714
# 24  22.363029     563.909774

# %%
plt.scatter(house_type_df.Distance, house_type_df.PRICE_BY_SQFT)
plt.xticks(rotation=60)
plt.figure
plt.show()
