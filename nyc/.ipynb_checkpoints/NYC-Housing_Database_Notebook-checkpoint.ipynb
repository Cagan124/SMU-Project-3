# %%
import pandas as pd
import matplotlib.pyplot as plt

import sqlalchemy
from sqlalchemy import create_engine, func, inspect, text

# %%
df = pd.read_csv("NY-House-Dataset_CLEANNNN.csv")
df.head()
# Out:
#                                          BROKERTITLE                TYPE  \
# 0        Brokered by Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                             Brokered by Sowae Corp      House for sale
# 2                                Brokered by COMPASS      Condo for sale
# 3  Brokered by Sotheby's International Realty - E...  Townhouse for sale
# 4                             Brokered by Sowae Corp      House for sale
#
#       PRICE  BEDS      BATH  PROPERTYSQFT                  ADDRESS  \
# 0    315000     2  2.000000        1400.0     2 E 55th St Unit 803
# 1    260000     4  2.000000        2015.0         620 Sinclair Ave
# 2     69000     3  1.000000         445.0  2 E 55th St Unit 908W33
# 3  55000000     7  2.373861       14175.0              5 E 64th St
# 4    690000     5  2.000000        4004.0              584 Park Pl
#
#                      STATE                                MAIN_ADDRESS  \
# 0       New York, NY 10022      2 E 55th St Unit 803New York, NY 10022
# 1  Staten Island, NY 10312     620 Sinclair AveStaten Island, NY 10312
# 2      Manhattan, NY 10022  2 E 55th St Unit 908W33Manhattan, NY 10022
# 3       New York, NY 10065               5 E 64th StNew York, NY 10065
# 4       Brooklyn, NY 11238               584 Park PlBrooklyn, NY 11238
#
#   ADMINISTRATIVE_AREA_LEVEL_2  ...      SUBLOCALITY       STREET_NAME  \
# 0             New York County  ...        Manhattan  East 55th Street
# 1               United States  ...  Richmond County     Staten Island
# 2               United States  ...  New York County          New York
# 3               United States  ...  New York County          New York
# 4               United States  ...     Kings County          Brooklyn
#
#           LONG_NAME                                  FORMATTED_ADDRESS  \
# 0   Regis Residence  Regis Residence, 2 E 55th St #803, New York, N...
# 1   Sinclair Avenue     620 Sinclair Ave, Staten Island, NY 10312, USA
# 2  East 55th Street               2 E 55th St, New York, NY 10022, USA
# 3  East 64th Street               5 E 64th St, New York, NY 10065, USA
# 4        Park Place               584 Park Pl, Brooklyn, NY 11238, USA
#
#     LATITUDE  LONGITUDE   Distance  PRICE_BY_SQFT        Borough House_Type
# 0  40.761255 -73.974483   2.950061     225.000000            NaN      Condo
# 1  40.541805 -74.196109  18.901470     129.032258  Staten Island      House
# 2  40.761398 -73.974613   2.961863     155.056180            NaN      Condo
# 3  40.767224 -73.969856   3.111680    3880.070547            NaN  Townhouse
# 4  40.674363 -73.958725   4.076335     172.327672       Brooklyn      House
#
# [5 rows x 21 columns]

# %%
engine = create_engine("sqlite:///NY-House-Dataset_CLEANNNN.sqlite")

df.to_sql("NYC_Houses", con=engine, if_exists="replace", index=False)
# Out:
# 4141

# %%
# explore and understand the data

# Create the inspector and connect it to the engine
inspector = inspect(engine)

# Collect the names of tables within the database
tables = inspector.get_table_names()

# Using the inspector to print the column names within each table and its types
for table in tables:
    print(table)
    columns = inspector.get_columns(table)
    for column in columns:
        print(column["name"], column["type"])
        
    print()
# Out:
# NYC_Houses
# BROKERTITLE TEXT
# TYPE TEXT
# PRICE BIGINT
# BEDS BIGINT
# BATH FLOAT
# PROPERTYSQFT FLOAT
# ADDRESS TEXT
# STATE TEXT
# MAIN_ADDRESS TEXT
# ADMINISTRATIVE_AREA_LEVEL_2 TEXT
# LOCALITY TEXT
# SUBLOCALITY TEXT
# STREET_NAME TEXT
# LONG_NAME TEXT
# FORMATTED_ADDRESS TEXT
# LATITUDE FLOAT
# LONGITUDE FLOAT
# Distance FLOAT
# PRICE_BY_SQFT FLOAT
# Borough TEXT
# House_Type TEXT

# %%
price = 500000

# allow the user to select ALL or a specific state
if price == "All":
    where_clause = "1=1"
else:
    where_clause = f"PRICE <= '{price}'"

query = f"""
        SELECT
            *
        FROM
            NYC_Houses
        WHERE
            {where_clause};
"""

print(query)
# Out:
#         SELECT
#             *
#         FROM
#             NYC_Houses
#         WHERE
#             PRICE <= '500000';

# %%
df_map = pd.read_sql(text(query), con=engine)
df_map.head()
# Out:
#                                    BROKERTITLE            TYPE   PRICE  BEDS  \
# 0  Brokered by Douglas Elliman  -111 Fifth Ave  Condo for sale  315000     2
# 1                       Brokered by Sowae Corp  House for sale  260000     4
# 2                          Brokered by COMPASS  Condo for sale   69000     3
# 3               Brokered by Pantiga Group Inc.  Co-op for sale  265000     1
# 4             Brokered by CENTURY 21 MK Realty  Co-op for sale  440000     2
#
#    BATH  PROPERTYSQFT                  ADDRESS                    STATE  \
# 0   2.0        1400.0     2 E 55th St Unit 803       New York, NY 10022
# 1   2.0        2015.0         620 Sinclair Ave  Staten Island, NY 10312
# 2   1.0         445.0  2 E 55th St Unit 908W33      Manhattan, NY 10022
# 3   1.0         750.0  875 Morrison Ave Apt 3M          Bronx, NY 10473
# 4   1.0         978.0   1350 Ocean Pkwy Apt 5G       Brooklyn, NY 11230
#
#                                  MAIN_ADDRESS ADMINISTRATIVE_AREA_LEVEL_2  \
# 0      2 E 55th St Unit 803New York, NY 10022             New York County
# 1     620 Sinclair AveStaten Island, NY 10312               United States
# 2  2 E 55th St Unit 908W33Manhattan, NY 10022               United States
# 3      875 Morrison Ave Apt 3MBronx, NY 10473                Bronx County
# 4    1350 Ocean Pkwy Apt 5GBrooklyn, NY 11230                    New York
#
#    ...      SUBLOCALITY       STREET_NAME         LONG_NAME  \
# 0  ...        Manhattan  East 55th Street   Regis Residence
# 1  ...  Richmond County     Staten Island   Sinclair Avenue
# 2  ...  New York County          New York  East 55th Street
# 3  ...       East Bronx   Morrison Avenue       Parking lot
# 4  ...         Brooklyn           Midwood              1350
#
#                                    FORMATTED_ADDRESS   LATITUDE  LONGITUDE  \
# 0  Regis Residence, 2 E 55th St #803, New York, N...  40.761255 -73.974483
# 1     620 Sinclair Ave, Staten Island, NY 10312, USA  40.541805 -74.196109
# 2               2 E 55th St, New York, NY 10022, USA  40.761398 -73.974613
# 3  Parking lot, 875 Morrison Ave #3m, Bronx, NY 1...  40.821586 -73.874089
# 4       1350 Ocean Pkwy #5g, Brooklyn, NY 11230, USA  40.615738 -73.969694
#
#     Distance  PRICE_BY_SQFT        Borough House_Type
# 0   2.950061     225.000000           None      Condo
# 1  18.901470     129.032258  Staten Island      House
# 2   2.961863     155.056180           None      Condo
# 3   7.053388     353.333333           None      Co-op
# 4   8.139742     449.897751           None      Co-op
#
# [5 rows x 21 columns]

# %%
num_beds = 3

# allow the user to select ALL or a specific state
if num_beds == "All":
    where_clause = "1=1"
else:
    where_clause = f"BEDS <= '{num_beds}'"

query = f"""
        SELECT
            *
        FROM
            NYC_Houses
        WHERE
            {where_clause};
"""

print(query)
# Out:
#         SELECT
#             *
#         FROM
#             NYC_Houses
#         WHERE
#             BEDS <= '3';

# %%
df_map = pd.read_sql(text(query), con=engine)
df_map.head()
# Out:
#                                      BROKERTITLE            TYPE   PRICE  \
# 0    Brokered by Douglas Elliman  -111 Fifth Ave  Condo for sale  315000
# 1                            Brokered by COMPASS  Condo for sale   69000
# 2  Brokered by Douglas Elliman - 575 Madison Ave  Condo for sale  899500
# 3                 Brokered by Pantiga Group Inc.  Co-op for sale  265000
# 4               Brokered by CENTURY 21 MK Realty  Co-op for sale  440000
#
#    BEDS  BATH  PROPERTYSQFT                  ADDRESS                STATE  \
# 0     2   2.0   1400.000000     2 E 55th St Unit 803   New York, NY 10022
# 1     3   1.0    445.000000  2 E 55th St Unit 908W33  Manhattan, NY 10022
# 2     2   2.0   2184.207862   157 W 126th St Unit 1B   New York, NY 10027
# 3     1   1.0    750.000000  875 Morrison Ave Apt 3M      Bronx, NY 10473
# 4     2   1.0    978.000000   1350 Ocean Pkwy Apt 5G   Brooklyn, NY 11230
#
#                                  MAIN_ADDRESS ADMINISTRATIVE_AREA_LEVEL_2  \
# 0      2 E 55th St Unit 803New York, NY 10022             New York County
# 1  2 E 55th St Unit 908W33Manhattan, NY 10022               United States
# 2    157 W 126th St Unit 1BNew York, NY 10027                    New York
# 3      875 Morrison Ave Apt 3MBronx, NY 10473                Bronx County
# 4    1350 Ocean Pkwy Apt 5GBrooklyn, NY 11230                    New York
#
#    ...      SUBLOCALITY       STREET_NAME         LONG_NAME  \
# 0  ...        Manhattan  East 55th Street   Regis Residence
# 1  ...  New York County          New York  East 55th Street
# 2  ...         New York         Manhattan               157
# 3  ...       East Bronx   Morrison Avenue       Parking lot
# 4  ...         Brooklyn           Midwood              1350
#
#                                    FORMATTED_ADDRESS   LATITUDE  LONGITUDE  \
# 0  Regis Residence, 2 E 55th St #803, New York, N...  40.761255 -73.974483
# 1               2 E 55th St, New York, NY 10022, USA  40.761398 -73.974613
# 2        157 W 126th St #1b, New York, NY 10027, USA  40.809448 -73.946777
# 3  Parking lot, 875 Morrison Ave #3m, Bronx, NY 1...  40.821586 -73.874089
# 4       1350 Ocean Pkwy #5g, Brooklyn, NY 11230, USA  40.615738 -73.969694
#
#    Distance  PRICE_BY_SQFT  Borough House_Type
# 0  2.950061     225.000000     None      Condo
# 1  2.961863     155.056180     None      Condo
# 2  5.480580     411.819779     None      Condo
# 3  7.053388     353.333333     None      Co-op
# 4  8.139742     449.897751     None      Co-op
#
# [5 rows x 21 columns]

# %%
num_baths = 2

# allow the user to select ALL or a specific state
if num_baths == "All":
    where_clause = "1=1"
else:
    where_clause = f"BATH <= '{num_baths}'"

query = f"""
        SELECT
            *
        FROM
            NYC_Houses
        WHERE
            {where_clause};
"""

print(query)
# Out:
#         SELECT
#             *
#         FROM
#             NYC_Houses
#         WHERE
#             BATH <= '2';

# %%
df_map = pd.read_sql(text(query), con=engine)
df_map.head()
# Out:
#                                      BROKERTITLE            TYPE   PRICE  \
# 0    Brokered by Douglas Elliman  -111 Fifth Ave  Condo for sale  315000
# 1                         Brokered by Sowae Corp  House for sale  260000
# 2                            Brokered by COMPASS  Condo for sale   69000
# 3                         Brokered by Sowae Corp  House for sale  690000
# 4  Brokered by Douglas Elliman - 575 Madison Ave  Condo for sale  899500
#
#    BEDS  BATH  PROPERTYSQFT                  ADDRESS                    STATE  \
# 0     2   2.0   1400.000000     2 E 55th St Unit 803       New York, NY 10022
# 1     4   2.0   2015.000000         620 Sinclair Ave  Staten Island, NY 10312
# 2     3   1.0    445.000000  2 E 55th St Unit 908W33      Manhattan, NY 10022
# 3     5   2.0   4004.000000              584 Park Pl       Brooklyn, NY 11238
# 4     2   2.0   2184.207862   157 W 126th St Unit 1B       New York, NY 10027
#
#                                  MAIN_ADDRESS ADMINISTRATIVE_AREA_LEVEL_2  \
# 0      2 E 55th St Unit 803New York, NY 10022             New York County
# 1     620 Sinclair AveStaten Island, NY 10312               United States
# 2  2 E 55th St Unit 908W33Manhattan, NY 10022               United States
# 3               584 Park PlBrooklyn, NY 11238               United States
# 4    157 W 126th St Unit 1BNew York, NY 10027                    New York
#
#    ...      SUBLOCALITY       STREET_NAME         LONG_NAME  \
# 0  ...        Manhattan  East 55th Street   Regis Residence
# 1  ...  Richmond County     Staten Island   Sinclair Avenue
# 2  ...  New York County          New York  East 55th Street
# 3  ...     Kings County          Brooklyn        Park Place
# 4  ...         New York         Manhattan               157
#
#                                    FORMATTED_ADDRESS   LATITUDE  LONGITUDE  \
# 0  Regis Residence, 2 E 55th St #803, New York, N...  40.761255 -73.974483
# 1     620 Sinclair Ave, Staten Island, NY 10312, USA  40.541805 -74.196109
# 2               2 E 55th St, New York, NY 10022, USA  40.761398 -73.974613
# 3               584 Park Pl, Brooklyn, NY 11238, USA  40.674363 -73.958725
# 4        157 W 126th St #1b, New York, NY 10027, USA  40.809448 -73.946777
#
#     Distance  PRICE_BY_SQFT        Borough House_Type
# 0   2.950061     225.000000           None      Condo
# 1  18.901470     129.032258  Staten Island      House
# 2   2.961863     155.056180           None      Condo
# 3   4.076335     172.327672       Brooklyn      House
# 4   5.480580     411.819779           None      Condo
#
# [5 rows x 21 columns]

# %%
house_type = 'House'

# allow the user to select ALL or a specific state
if house_type == "All":
    where_clause = "1=1"
else:
    where_clause = f"House_Type == '{house_type}'"

query = f"""
        SELECT
            *
        FROM
            NYC_Houses
        WHERE
            {where_clause};
"""

print(query)
# Out:
#         SELECT
#             *
#         FROM
#             NYC_Houses
#         WHERE
#             House_Type == 'House';

# %%
df_map = pd.read_sql(text(query), con=engine)
df_map.head()
# Out:
#                          BROKERTITLE            TYPE     PRICE  BEDS  BATH  \
# 0             Brokered by Sowae Corp  House for sale    260000     4   2.0
# 1             Brokered by Sowae Corp  House for sale    690000     5   2.0
# 2  Brokered by Connie Profaci Realty  House for sale  16800000     8  16.0
# 3    Brokered by Radiant Estates LLC  House for sale    639999     3   2.0
# 4        Brokered by Elizabeth Marra  House for sale    750000     2   2.0
#
#    PROPERTYSQFT           ADDRESS                    STATE  \
# 0        2015.0  620 Sinclair Ave  Staten Island, NY 10312
# 1        4004.0       584 Park Pl       Brooklyn, NY 11238
# 2       33000.0   177 Benedict Rd  Staten Island, NY 10304
# 3        1260.0      27 Clove Way  Staten Island, NY 10301
# 4        1330.0    280 Loretto St  Staten Island, NY 10307
#
#                               MAIN_ADDRESS ADMINISTRATIVE_AREA_LEVEL_2  ...  \
# 0  620 Sinclair AveStaten Island, NY 10312               United States  ...
# 1            584 Park PlBrooklyn, NY 11238               United States  ...
# 2   177 Benedict RdStaten Island, NY 10304               United States  ...
# 3      27 Clove WayStaten Island, NY 10301               United States  ...
# 4    280 Loretto StStaten Island, NY 10307               United States  ...
#
#        SUBLOCALITY    STREET_NAME        LONG_NAME  \
# 0  Richmond County  Staten Island  Sinclair Avenue
# 1     Kings County       Brooklyn       Park Place
# 2  Richmond County  Staten Island    Benedict Road
# 3  Richmond County  Staten Island        Clove Way
# 4  Richmond County  Staten Island   Loretto Street
#
#                                 FORMATTED_ADDRESS   LATITUDE  LONGITUDE  \
# 0  620 Sinclair Ave, Staten Island, NY 10312, USA  40.541805 -74.196109
# 1            584 Park Pl, Brooklyn, NY 11238, USA  40.674363 -73.958725
# 2   177 Benedict Rd, Staten Island, NY 10304, USA  40.595002 -74.106424
# 3      27 Clove Way, Staten Island, NY 10301, USA  40.620740 -74.111436
# 4    280 Loretto St, Staten Island, NY 10307, USA  40.503979 -74.239655
#
#     Distance  PRICE_BY_SQFT        Borough House_Type
# 0  18.901470     129.032258  Staten Island      House
# 1   4.076335     172.327672       Brooklyn      House
# 2  12.972564     509.090909  Staten Island      House
# 3  11.953013     507.935714           None      House
# 4  22.363029     563.909774           None      House
#
# [5 rows x 21 columns]

# %%
house_type = 'All'
price = 500000
num_beds = 3
num_baths = 2
price_by_sqft = 250
distance = 12


# allow the user to select ALL or a specific state
if house_type == "All":
    where_clause1 = "1=1"
else:
    where_clause1 = f"House_Type == '{house_type}'"
    
if price == "All":
    where_clause2 = "1=1"
else:
    where_clause2 = f"PRICE <= '{price}'"
    
if num_beds == "All":
    where_clause3 = "1=1"
else:
    where_clause3 = f"BEDS <= '{num_beds}'"
    
if num_baths == "All":
    where_clause4 = "1=1"
else:
    where_clause4 = f"BATH <= '{num_baths}'"

if price_by_sqft == "All":
    where_clause5 = "1=1"
else:
    where_clause5 = f"PRICE_BY_SQFT <= '{price_by_sqft}'"
    
if distance == "All":
    where_clause6 = "1=1"
else:
    where_clause6 = f"Distance <= '{distance}'"
    
query = f"""
        SELECT
            *
        FROM
            NYC_Houses
        WHERE
            {where_clause1} AND {where_clause2} AND {where_clause3} AND {where_clause4} AND {where_clause5} AND {where_clause6};
"""

print(query)
# Out:
#         SELECT
#             *
#         FROM
#             NYC_Houses
#         WHERE
#             1=1 AND PRICE <= '500000' AND BEDS <= '3' AND BATH <= '2' AND PRICE_BY_SQFT <= '250' AND Distance <= '12';

# %%
df_map = pd.read_sql(text(query), con=engine)
df_map.head()
# Out:
#                                          BROKERTITLE            TYPE   PRICE  \
# 0        Brokered by Douglas Elliman  -111 Fifth Ave  Condo for sale  315000
# 1                                Brokered by COMPASS  Condo for sale   69000
# 2                                Brokered by COMPASS  Co-op for sale  259000
# 3         Brokered by Jamie & Connie Real Estate Grp  Co-op for sale  430000
# 4  Brokered by Nest Seekers International, Long I...  Co-op for sale  325000
#
#    BEDS  BATH  PROPERTYSQFT                   ADDRESS  \
# 0     2   2.0   1400.000000      2 E 55th St Unit 803
# 1     3   1.0    445.000000   2 E 55th St Unit 908W33
# 2     3   1.0   2184.207862     34-41 85th St Unit 1D
# 3     2   2.0   2184.207862  91-15 Lamont Ave Unit 6D
# 4     1   1.0   2184.207862     35-45 81st St Unit E1
#
#                        STATE                                    MAIN_ADDRESS  \
# 0         New York, NY 10022          2 E 55th St Unit 803New York, NY 10022
# 1        Manhattan, NY 10022      2 E 55th St Unit 908W33Manhattan, NY 10022
# 2  Jackson Heights, NY 11372  34-41 85th St Unit 1DJackson Heights, NY 11372
# 3         Elmhurst, NY 11373      91-15 Lamont Ave Unit 6DElmhurst, NY 11373
# 4           Queens, NY 11372           35-45 81st St Unit E1Queens, NY 11372
#
#   ADMINISTRATIVE_AREA_LEVEL_2  ...      SUBLOCALITY       STREET_NAME  \
# 0             New York County  ...        Manhattan  East 55th Street
# 1               United States  ...  New York County          New York
# 2                    New York  ...           Queens          Flushing
# 3                    New York  ...           Queens          Elmhurst
# 4                    New York  ...           Queens   Jackson Heights
#
#           LONG_NAME                                  FORMATTED_ADDRESS  \
# 0   Regis Residence  Regis Residence, 2 E 55th St #803, New York, N...
# 1  East 55th Street               2 E 55th St, New York, NY 10022, USA
# 2             34-41         34-41 85th St #1b, Flushing, NY 11372, USA
# 3             91-15      91-15 Lamont Ave #6d, Elmhurst, NY 11373, USA
# 4             35-45   35-45 81st St e1, Jackson Heights, NY 11372, USA
#
#     LATITUDE  LONGITUDE  Distance  PRICE_BY_SQFT  Borough House_Type
# 0  40.761255 -73.974483  2.950061     225.000000     None      Condo
# 1  40.761398 -73.974613  2.961863     155.056180     None      Condo
# 2  40.753119 -73.881876  3.197436     118.578458     None      Co-op
# 3  40.743864 -73.874572  3.305645     196.867710     None      Co-op
# 4  40.750508 -73.885136  2.961560     148.795362     None      Co-op
#
# [5 rows x 21 columns]
